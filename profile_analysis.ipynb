# %%
import numpy as np
import matplotlib.pyplot as plt
import pydicom

from pylinac import FieldProfileAnalysis, Centering, Normalization, Edge
from pylinac.metrics.profile import (
    PenumbraLeftMetric,
    PenumbraRightMetric,
    SymmetryAreaMetric,
    FlatnessDifferenceMetric,
)

from metrics import FlatnessCalculationByVariance
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 13
#       9     SymmetryAreaMetric,
#      10     FlatnessDifferenceMetric,
#      11 )
#      12
# ---> 13 from metrics import FlatnessCalculationByVariance
#
# File h:\junecode\testing\metrics.py:83
#      81 path = 'Solstice-m12_d18_2025-FS_EPID_MLC 10x38.dcm'
#      82 field_analyzer = FieldProfileAnalysis(path)
# ---> 83 field_analyzer.analyze(
#      84     centering=Centering.BEAM_CENTER,
#      85     # x_width=0.02,
#      86     # y_width=0.02,
#      87     normalization=Normalization.BEAM_CENTER,
#      88     edge_type=Edge.INFLECTION_DERIVATIVE,
#      89     ground=True,
#      90     metrics=(
#      91         PenumbraLeftMetric(),
#      92         PenumbraRightMetric(),
#      93         SymmetryAreaMetric(),
#      94         FlatnessDifferenceMetric(),
#      95         FlatnessCalculationByVariance(),
#      96     ),
#      97 )
#      98 print(field_analyzer.results())
#      99 field_analyzer.plot_analyzed_images()
#
# File h:\junecode\testing\.venv\Lib\site-packages\pylinac\core\warnings.py:43, in capture_warnings_method_wrapper.<locals>.wrapper(self, *args, **kwargs)
#      41 warnings.simplefilter("always")
#      42 # Execute the original method
# ---> 43 result = method(self, *args, **kwargs)
#      44 # Process captured warnings
#      45 captured = []
#
# File h:\junecode\testing\.venv\Lib\site-packages\pylinac\field_profile_analysis.py:184, in FieldProfileAnalysis.analyze(self, centering, position, x_width, y_width, normalization, edge_type, invert, ground, metrics, **kwargs)
#     175 x_values, y_values = self._get_profile_values(position, x_width, y_width)
#     177 self.x_profile = PROFILES[self._edge_type](
#     178     values=x_values,
#     179     dpmm=self.image.dpmm,
#    (...)    182     **kwargs,
#     183 )
# --> 184 self.x_profile.compute(metrics=metrics)
#     185 self.y_profile = PROFILES[self._edge_type](
#     186     values=y_values,
#     187     dpmm=self.image.dpmm,
#    (...)    190     **kwargs,
#     191 )
#     192 # we have to deep copy otherwise the metrics get re-used and the y-metrics override the x-metrics
#
# File h:\junecode\testing\.venv\Lib\site-packages\pylinac\core\profile.py:570, in ProfileBase.compute(self, metrics)
#     566     self.metrics.append(metric)
#     567     key = uniquify(
#     568         list(values.keys()) + list(self.metric_values.keys()), metric.full_name
#     569     )
# --> 570     values[key] = metric.calculate()
#     571 self.metric_values |= values
#     572 if len(values) == 1:
#
# File h:\junecode\testing\metrics.py:50, in FlatnessCalculationByVariance.calculate(self)
#      48 def calculate(self) -> float:
#      49     """Calculate the flatness ratio of the profile."""
# ---> 50     values = self.profile.values()
#      51     cax_value = get_cax_value(values)
#      52     eighty_percent_value = cax_value * 0.8
#
# TypeError: 'numpy.ndarray' object is not callable

# %%
path = 'Solstice-m12_d18_2025-FS_EPID_MLC 10x38.dcm'
field_analyzer = FieldProfileAnalysis(path)
field_analyzer.analyze(
    centering=Centering.BEAM_CENTER,
    # x_width=0.02,
    # y_width=0.02,
    normalization=Normalization.BEAM_CENTER,
    edge_type=Edge.INFLECTION_DERIVATIVE,
    ground=True,
    metrics=(
        PenumbraLeftMetric(),
        PenumbraRightMetric(),
        SymmetryAreaMetric(),
        FlatnessDifferenceMetric(),
        FlatnessCalculationByVariance(),
    ),
)
print(field_analyzer.results())
field_analyzer.plot_analyzed_images()

# %%
path = 'EPID_Jaw 10x10.dcm'
field_analyzer = FieldProfileAnalysis(path)
field_analyzer.analyze()
field_analyzer.plot_analyzed_images(show_grid=True, mirror="beam")
# Out:
# [<Figure size 640x480 with 2 Axes>,
#  <Figure size 640x480 with 2 Axes>,
#  <Figure size 640x480 with 1 Axes>]
