# %%
from matplotlib import pyplot as plt

from pylinac.core.image_generator import AS1200Image, AS1000Image
import pylinac.core.image_generator.layers as layers

import numpy as np

import pydicom as dicom

from datetime import datetime, timezone
from pathlib import Path

# %% [markdown]
# Barebones notebook to read dcm files, check metadata and save as png. There are many (unlabeled) examples.

# %%
image_path = 'test_images\\Solstice-m05_d19_2026-Winston_Coll_000.dcm'
ds = dicom.dcmread(image_path)

print(ds.Rows, ds.Columns)
print("SID: ", ds.RTImageSID)

plt.grid(False)
plt.imshow(ds.pixel_array)
plt.imsave('test_images\\Solstice-m05_d19_2026-Winston_Coll_000.png', ds.pixel_array)
# Out:
# 1190 1190
# SID:  1500.01617510173

# %%
#image_path = 'artifact_vertical_bar_10x10.dcm'
#image_path = 'Solstice-m12_d18_2025-FS_EPID_MLC 10x38.dcm'
image_path = 'Solstice-m12_d18_2025-FS_EPID_Jaw 10x10.dcm'
ds = dicom.dcmread(image_path)

plt.grid(True)
plt.imshow(ds.pixel_array)

# %%
def add_metadata(file_name):
    ds = dicom.dcmread(file_name)
    epoch = datetime(1970, 1, 1, tzinfo=timezone.utc)
    
    ds.InstanceCreationDate = datetime.now().strftime('%Y%m%d')
    ds.InstanceCreationTime = datetime.now().strftime('%H%M%S')
    ds.AcquisitionDate = datetime.now().strftime('%Y%m%d')
    ds.AcquisitionTime = datetime.now().strftime('%H%M%S')

    ds.StationName = 'TDCreator'
    ds.Manufacturer = 'TDCreator'
    ds.OperatorsName = 'TDCreator'

    ds.PatientBirthDate = epoch.strftime('%Y%m%d')
    ds.PatientBirthTime = epoch.strftime('%H%M%S')

    #TODO: Setup a way to dynamically pull software version
    ds.SoftwareVersions = '1.0'

    ds.PixelRepresentation = 0
    ds.PixelIntensityRelationship = 'LIN'
    ds.PixelIntensityRelationshipSign = 1

    ds.BeamLimitingDeviceAngle = 0.0
    ds.PatientSupportAngle = 0.0

    ds.TableTopVerticalPosition = 0.0
    ds.TableTopLongitudinalPosition = 20.0
    ds.TableTopLateralPosition = 0.0
    ds.TableTopPitchAngle = 0.0
    ds.TableTopRollAngle = 0.0

    exposure_dataset = dicom.Dataset()
    exposure_dataset.KVP = 6000.0
    exposure_dataset.ExposureTime = 1
    exposure_dataset.MetersetExposure = 100

    beam_limiting_device_dataset = dicom.Dataset()
    beam_limiting_device_dataset.LeafJawPositions = [-50.0, 50.0]
    exposure_dataset.GantryAngle = ds.GantryAngle
    exposure_dataset.TableTopVerticalPosition = ds.TableTopVerticalPosition
    exposure_dataset.TableTopLongitudinalPosition = ds.TableTopLongitudinalPosition
    exposure_dataset.TableTopLateralPosition = ds.TableTopLateralPosition
    exposure_dataset.TableTopPitchAngle = ds.TableTopPitchAngle
    exposure_dataset.TableTopRollAngle = ds.TableTopRollAngle
    exposure_dataset.BeamLimitingDeviceSequence = dicom.Sequence([beam_limiting_device_dataset])

    ds.ExposureSequence = dicom.Sequence([exposure_dataset])
    ds.IsocenterPosition = [0.0, 0.0, 0.0]

    print(ds)
    ds.save_as(file_name)

# %%
#image_path = 'lightrad.dcm'
image_path = 'EPID Perfect Open Field 10x10.dcm'

add_metadata(image_path)

ds = dicom.dcmread(image_path)



plt.grid(True)
plt.imshow(ds.pixel_array)
# Out:
# Dataset.file_meta -------------------------------
# (0002, 0000) File Meta Information Group Length  UL: 246
# (0002, 0001) File Meta Information Version       OB: b'\x00\x01'
# (0002, 0002) Media Storage SOP Class UID         UI: RT Image Storage
# (0002, 0003) Media Storage SOP Instance UID      UI: 1.2.826.0.1.3680043.8.498.70636895888248008205464519676538144707
# (0002, 0010) Transfer Syntax UID                 UI: Explicit VR Little Endian
# (0002, 0012) Implementation Class UID            UI: 1.2.826.0.1.3680043.8.498.51351858128105644228406984717870474999
# (0002, 0013) Implementation Version Name         SH: 'PYDICOM 2.4.5'
# -------------------------------------------------
# (0008, 0008) Image Type                          CS: ['ORIGINAL', 'PRIMARY', 'OTHER']
# (0008, 0012) Instance Creation Date              DA: '20260609'
# (0008, 0013) Instance Creation Time              TM: '111604'
# (0008, 0016) SOP Class UID                       UI: RT Image Storage
# (0008, 0018) SOP Instance UID                    UI: 1.2.826.0.1.3680043.8.498.70636895888248008205464519676538144707
# (0008, 0020) Study Date                          DA: '20260519'
# (0008, 0022) Acquisition Date                    DA: '20260609'
# (0008, 0023) Content Date                        DA: '20260519'
# (0008, 0030) Study Time                          TM: '130432'
# (0008, 0032) Acquisition Time                    TM: '111604'
# (0008, 0033) Content Time                        TM: '130432'
# (0008, 0060) Modality                            CS: 'RTIMAGE'
# (0008, 0064) Conversion Type                     CS: 'WSD'
# (0008, 0070) Manufacturer                        LO: 'TDCreator'
# (0008, 1010) Station Name                        SH: 'TDCreator'
# (0008, 1070) Operators' Name                     PN: 'TDCreator'
# (0010, 0010) Patient's Name                      PN: 'Pylinac array'
# (0010, 0020) Patient ID                          LO: '123456789'
# (0010, 0030) Patient's Birth Date                DA: '19700101'
# (0010, 0032) Patient's Birth Time                TM: '000000'
# (0010, 0040) Patient's Sex                       CS: 'O'
# (0018, 1020) Software Versions                   LO: '1.0'
# (0020, 000d) Study Instance UID                  UI: 1.2.826.0.1.3680043.8.498.69711926048395397669746538188479613596
# (0020, 000e) Series Instance UID                 UI: 1.2.826.0.1.3680043.8.498.80929360888567374497736630862336703773
# (0028, 0002) Samples per Pixel                   US: 1
# (0028, 0004) Photometric Interpretation          CS: 'MONOCHROME2'
# (0028, 0010) Rows                                US: 1280
# (0028, 0011) Columns                             US: 1280
# (0028, 0100) Bits Allocated                      US: 16
# (0028, 0101) Bits Stored                         US: 16
# (0028, 0102) High Bit                            US: 15
# (0028, 0103) Pixel Representation                US: 0
# (0028, 1040) Pixel Intensity Relationship        CS: 'LIN'
# (0028, 1041) Pixel Intensity Relationship Sign   SS: 1
# (3002, 0002) RT Image Label                      SH: 'Pylinac image'
# (3002, 000c) RT Image Plane                      CS: 'NORMAL'
# (3002, 0011) Image Plane Pixel Spacing           DS: [0.336, 0.336]
# (3002, 0012) RT Image Position                   DS: [-8.459527559055118, -8.459527559055118]
# (3002, 0020) Radiation Machine Name              SH: 'Pylinac'
# (3002, 0022) Radiation Machine SAD               DS: '1000.0'
# (3002, 0026) RT Image SID                        DS: '1500.0'
# (3002, 0030)  Exposure Sequence  1 item(s) ----
#    (0018, 0060) KVP                                 DS: '6000.0'
#    (0018, 1150) Exposure Time                       IS: '1'
#    (3002, 0032) Meterset Exposure                   DS: '100.0'
#    (300a, 00b6)  Beam Limiting Device Sequence  1 item(s) ----
#       (300a, 011c) Leaf/Jaw Positions                  DS: [-50.0, 50.0]
#       ---------
#    (300a, 011e) Gantry Angle                        DS: '90.0'
#    (300a, 0128) Table Top Vertical Position         DS: '0.0'
#    (300a, 0129) Table Top Longitudinal Position     DS: '20.0'
#    (300a, 012a) Table Top Lateral Position          DS: '0.0'
#    (300a, 0140) Table Top Pitch Angle               FL: 0.0
#    (300a, 0144) Table Top Roll Angle                FL: 0.0
#    ---------
# (300a, 00b3) Primary Dosimeter Unit              CS: 'MU'
# (300a, 011e) Gantry Angle                        DS: '90.0'
# (300a, 0120) Beam Limiting Device Angle          DS: '0.0'
# (300a, 0122) Patient Support Angle               DS: '0.0'
# (300a, 0128) Table Top Vertical Position         DS: '0.0'
# (300a, 0129) Table Top Longitudinal Position     DS: '20.0'
# (300a, 012a) Table Top Lateral Position          DS: '0.0'
# (300a, 012c) Isocenter Position                  DS: [0.0, 0.0, 0.0]
# (300a, 0140) Table Top Pitch Angle               FL: 0.0
# (300a, 0144) Table Top Roll Angle                FL: 0.0
# (7fe0, 0010) Pixel Data                          OW: Array of 3276800 elements

# %%
image_path = "artifact_detector_decrease_10x10.dcm"

ds = dicom.dcmread(image_path)

print(ds)

plt.grid(True)
plt.imshow(ds.pixel_array)
# Out:
# Dataset.file_meta -------------------------------
# (0002, 0000) File Meta Information Group Length  UL: 246
# (0002, 0001) File Meta Information Version       OB: b'\x00\x01'
# (0002, 0002) Media Storage SOP Class UID         UI: RT Image Storage
# (0002, 0003) Media Storage SOP Instance UID      UI: 1.2.826.0.1.3680043.8.498.50618629455210079125875040348961292326
# (0002, 0010) Transfer Syntax UID                 UI: Explicit VR Little Endian
# (0002, 0012) Implementation Class UID            UI: 1.2.826.0.1.3680043.8.498.40418554370017569775515068514020833315
# (0002, 0013) Implementation Version Name         SH: 'PYDICOM 2.4.5'
# -------------------------------------------------
# (0008, 0008) Image Type                          CS: ['ORIGINAL', 'PRIMARY', 'OTHER']
# (0008, 0012) Instance Creation Date              DA: '20260610'
# (0008, 0013) Instance Creation Time              TM: '105607'
# (0008, 0016) SOP Class UID                       UI: RT Image Storage
# (0008, 0018) SOP Instance UID                    UI: 1.2.826.0.1.3680043.8.498.50618629455210079125875040348961292326
# (0008, 0020) Study Date                          DA: '20260610'
# (0008, 0022) Acquisition Date                    DA: '20260610'
# (0008, 0023) Content Date                        DA: '20260610'
# (0008, 0030) Study Time                          TM: '105607'
# (0008, 0032) Acquisition Time                    TM: '105607'
# (0008, 0033) Content Time                        TM: '105607'
# (0008, 0060) Modality                            CS: 'RTIMAGE'
# (0008, 0064) Conversion Type                     CS: 'WSD'
# (0008, 0070) Manufacturer                        LO: 'TDCreator'
# (0008, 1010) Station Name                        SH: 'TDCreator'
# (0008, 1070) Operators' Name                     PN: 'TDCreator'
# (0010, 0010) Patient's Name                      PN: 'Pylinac array'
# (0010, 0020) Patient ID                          LO: '123456789'
# (0010, 0030) Patient's Birth Date                DA: '19700101'
# (0010, 0032) Patient's Birth Time                TM: '000000'
# (0010, 0040) Patient's Sex                       CS: 'O'
# (0018, 1020) Software Versions                   LO: '0.1.0'
# (0020, 000d) Study Instance UID                  UI: 1.2.826.0.1.3680043.8.498.51151653476929150900518234634047023277
# (0020, 000e) Series Instance UID                 UI: 1.2.826.0.1.3680043.8.498.85725318663269319562559502652592721129
# (0028, 0002) Samples per Pixel                   US: 1
# (0028, 0004) Photometric Interpretation          CS: 'MONOCHROME2'
# (0028, 0010) Rows                                US: 1280
# (0028, 0011) Columns                             US: 1280
# (0028, 0100) Bits Allocated                      US: 64
# (0028, 0101) Bits Stored                         US: 64
# (0028, 0102) High Bit                            US: 63
# (0028, 0103) Pixel Representation                US: 0
# (0028, 1040) Pixel Intensity Relationship        CS: 'LIN'
# (0028, 1041) Pixel Intensity Relationship Sign   SS: 1
# (3002, 0002) RT Image Label                      SH: 'Pylinac image'
# (3002, 000c) RT Image Plane                      CS: 'NORMAL'
# (3002, 0011) Image Plane Pixel Spacing           DS: [0.336, 0.336]
# (3002, 0012) RT Image Position                   DS: [-8.459527559055118, -8.459527559055118]
# (3002, 0020) Radiation Machine Name              SH: 'Pylinac'
# (3002, 0022) Radiation Machine SAD               DS: '1000.0'
# (3002, 0026) RT Image SID                        DS: '1500.0'
# (3002, 0030)  Exposure Sequence  1 item(s) ----
#    (0018, 0060) KVP                                 DS: '6000.0'
#    (0018, 1150) Exposure Time                       IS: '1'
#    (3002, 0032) Meterset Exposure                   DS: '100.0'
#    (300a, 00b6)  Beam Limiting Device Sequence  1 item(s) ----
#       (300a, 011c) Leaf/Jaw Positions                  DS: [-50.0, 50.0]
#       ---------
#    (300a, 011e) Gantry Angle                        DS: '0.0'
#    (300a, 0128) Table Top Vertical Position         DS: '0.0'
#    (300a, 0129) Table Top Longitudinal Position     DS: '20.0'
#    (300a, 012a) Table Top Lateral Position          DS: '0.0'
#    (300a, 0140) Table Top Pitch Angle               FL: 0.0
#    (300a, 0144) Table Top Roll Angle                FL: 0.0
#    ---------
# (300a, 00b3) Primary Dosimeter Unit              CS: 'MU'
# (300a, 011e) Gantry Angle                        DS: '0.0'
# (300a, 0120) Beam Limiting Device Angle          DS: '0.0'
# (300a, 0122) Patient Support Angle               DS: '0.0'
# (300a, 0128) Table Top Vertical Position         DS: '0.0'
# (300a, 0129) Table Top Longitudinal Position     DS: '20.0'
# (300a, 012a) Table Top Lateral Position          DS: '0.0'
# (300a, 012c) Isocenter Position                  DS: [0.0, 0.0, 0.0]
# (300a, 0140) Table Top Pitch Angle               FL: 0.0
# (300a, 0144) Table Top Roll Angle                FL: 0.0
# (7fe0, 0008) Float Pixel Data                    OF: Array of 13107200 elements

# %%
file_path = Path("artifact_zero_4_columns_10x10.dcm")
as1200 = AS1200Image()
as1200.add_layer(layers.FilteredFieldLayer(
    field_size_mm=(100, 100)
))
as1200.add_layer(layers.GaussianFilterLayer())
center_column = as1200.image.shape[1] // 2
as1200.image[:, center_column - 40:center_column -36] = 0
as1200.generate_dicom(file_out_name=file_path, gantry_angle=0)
plt.imsave(file_path.with_suffix('.png'), as1200.image)
